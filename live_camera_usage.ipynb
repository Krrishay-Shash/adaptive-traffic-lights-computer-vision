# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("Yolo Capstone Project/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2026-06-29 16:22:11.015 python[99729:68479769] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 384x640 2 persons, 1 chair, 59.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 5.2ms preprocess, 59.9ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 76.3ms
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 1.1ms preprocess, 76.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 1 cell phone, 59.1ms
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 0.8ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 103.8ms
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 1.1ms preprocess, 103.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 55.6ms
# Confidence ---> 0.48
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 1.1ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.0ms
# Speed: 0.7ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 54.0ms
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 0.8ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 2026-06-29 16:22:15.194 python[99729:68479769] +[IMKClient subclass]: chose IMKClient_Modern
# 2026-06-29 16:22:15.194 python[99729:68479769] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 1 laptop, 1 cell phone, 47.6ms
# Confidence ---> 0.31
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 0.9ms preprocess, 47.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 50.2ms
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 8.1ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.8ms
# Speed: 0.8ms preprocess, 44.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 47.0ms
# Confidence ---> 0.66
# Class name --> tvmonitor
# Speed: 0.9ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 1 tv, 1 cell phone, 43.6ms
# Confidence ---> 0.59
# Class name --> pizza
# Confidence ---> 0.39
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 0.8ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 1 tv, 1 cell phone, 43.7ms
# Confidence ---> 0.84
# Class name --> cell phone
# Confidence ---> 0.56
# Class name --> pizza
# Confidence ---> 0.41
# Class name --> tvmonitor
# Speed: 0.8ms preprocess, 43.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 1 cell phone, 43.6ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.76
# Class name --> pizza
# Speed: 0.7ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 1 cell phone, 39.4ms
# Confidence ---> 0.88
# Class name --> cell phone
# Confidence ---> 0.68
# Class name --> pizza
# Speed: 0.8ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 2 cell phones, 43.9ms
# Confidence ---> 0.83
# Class name --> cell phone
# Confidence ---> 0.78
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.0ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 2 cell phones, 48.0ms
# Confidence ---> 0.71
# Class name --> pizza
# Confidence ---> 0.61
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.7ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 2 cell phones, 46.3ms
# Confidence ---> 0.77
# Class name --> pizza
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 0.6ms preprocess, 46.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 2 cell phones, 47.8ms
# Confidence ---> 0.67
# Class name --> pizza
# Confidence ---> 0.66
# Class name --> cell phone
# Confidence ---> 0.58
# Class name --> cell phone
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.7ms preprocess, 47.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pizza, 2 cell phones, 40.2ms
# Confidence ---> 0.59
# Class name --> cell phone
# Confidence ---> 0.53
# Class name --> pizza
# Confidence ---> 0.43
# Class name --> cell phone
# Speed: 0.8ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 2 cell phones, 58.8ms
# Confidence ---> 0.56
# Class name --> cell phone
# Confidence ---> 0.55
# Class name --> pizza
# Confidence ---> 0.41
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.9ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 2 cell phones, 37.8ms
# Confidence ---> 0.75
# Class name --> pizza
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.4
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.8ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 1 dining table, 2 cell phones, 41.4ms
# Confidence ---> 0.87
# Class name --> pizza
# Confidence ---> 0.73
# Class name --> cell phone
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.33
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 0.8ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 1 cell phone, 43.5ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> pizza
# Confidence ---> 0.53
# Class name --> person
# Speed: 0.7ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 1 cell phone, 44.3ms
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.79
# Class name --> pizza
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.8ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 pizza, 1 chair, 1 cell phone, 39.2ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.74
# Class name --> pizza
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Speed: 0.8ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 pizza, 1 cell phone, 38.5ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.8
# Class name --> pizza
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.7ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 pizza, 1 cell phone, 43.4ms
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.48
# Class name --> pizza
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.8ms preprocess, 43.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 42.1ms
# Confidence ---> 0.73
# Class name --> cell phone
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 0.7ms preprocess, 42.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 cell phone, 43.4ms
# Confidence ---> 0.63
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.7ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 43.4ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.8ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 1 tv, 45.5ms
# Confidence ---> 0.68
# Class name --> tvmonitor
# Confidence ---> 0.52
# Class name --> sports ball
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.8ms preprocess, 45.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 0.8ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 apple, 51.2ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.28
# Class name --> apple
# Speed: 1.1ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 apple, 40.0ms
# Confidence ---> 0.26
# Class name --> apple
# Speed: 2.2ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 0.9ms preprocess, 35.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 41.7ms
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.9ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 1 dining table, 35.9ms
# Confidence ---> 0.59
# Class name --> chair
# Confidence ---> 0.37
# Class name --> diningtable
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.7ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 1 couch, 3 dining tables, 1 remote, 40.6ms
# Confidence ---> 0.88
# Class name --> chair
# Confidence ---> 0.82
# Class name --> chair
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.43
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> diningtable
# Confidence ---> 0.34
# Class name --> sofa
# Confidence ---> 0.3
# Class name --> remote
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 0.7ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 chairs, 1 couch, 1 dining table, 42.3ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.47
# Class name --> diningtable
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> sofa
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.7ms preprocess, 42.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 1 dining table, 48.9ms
# Confidence ---> 0.79
# Class name --> chair
# Confidence ---> 0.65
# Class name --> chair
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.41
# Class name --> diningtable
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.8ms preprocess, 48.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 1 dining table, 44.5ms
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.54
# Class name --> diningtable
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.9ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 chairs, 2 dining tables, 54.7ms
# Confidence ---> 0.79
# Class name --> chair
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.41
# Class name --> diningtable
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.3
# Class name --> diningtable
# Speed: 0.9ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 dining table, 38.0ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.65
# Class name --> chair
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.54
# Class name --> diningtable
# Speed: 0.8ms preprocess, 38.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 1 dining table, 40.9ms
# Confidence ---> 0.79
# Class name --> chair
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.59
# Class name --> diningtable
# Confidence ---> 0.39
# Class name --> chair
# Speed: 0.9ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 dining table, 45.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.53
# Class name --> diningtable
# Confidence ---> 0.39
# Class name --> chair
# Speed: 0.6ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 chair, 1 dining table, 41.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.65
# Class name --> chair
# Confidence ---> 0.55
# Class name --> diningtable
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 1 dining table, 47.8ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.45
# Class name --> diningtable
# Speed: 0.9ms preprocess, 47.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 47.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.7
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> diningtable
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.9ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 38.5ms
# Confidence ---> 0.81
# Class name --> chair
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.8ms preprocess, 38.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 39.8ms
# Confidence ---> 0.79
# Class name --> chair
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.39
# Class name --> diningtable
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 1.0ms preprocess, 39.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 44.6ms
# Confidence ---> 0.78
# Class name --> chair
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.41
# Class name --> diningtable
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.8ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 46.2ms
# Confidence ---> 0.77
# Class name --> chair
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.5
# Class name --> diningtable
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.8ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 42.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.73
# Class name --> chair
# Confidence ---> 0.51
# Class name --> diningtable
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 1 chair, 1 dining table, 76.7ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.56
# Class name --> diningtable
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 76.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 37.1ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> diningtable
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.7ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 47.4ms
# Confidence ---> 0.82
# Class name --> chair
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.56
# Class name --> diningtable
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.9ms preprocess, 47.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 52.1ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.6
# Class name --> diningtable
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.0ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 43.9ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.6
# Class name --> diningtable
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 0.8ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 39.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.82
# Class name --> chair
# Confidence ---> 0.6
# Class name --> diningtable
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 0.7ms preprocess, 39.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 38.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.88
# Class name --> chair
# Confidence ---> 0.65
# Class name --> diningtable
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.9ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 41.3ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> diningtable
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.9ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 chairs, 1 dining table, 43.6ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.53
# Class name --> diningtable
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.8ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 chairs, 1 dining table, 44.4ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.51
# Class name --> diningtable
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> chair
# Speed: 0.7ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 43.4ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.52
# Class name --> diningtable
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.0ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 chairs, 1 dining table, 38.8ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.8ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 46.4ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.64
# Class name --> chair
# Confidence ---> 0.57
# Class name --> diningtable
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.8ms preprocess, 46.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 2 dining tables, 1 refrigerator, 45.0ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.32
# Class name --> refrigerator
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 0.8ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 bottles, 2 chairs, 1 dining table, 37.5ms
# Confidence ---> 0.75
# Class name --> chair
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.42
# Class name --> diningtable
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.7ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 42.9ms
# Confidence ---> 0.81
# Class name --> chair
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.58
# Class name --> diningtable
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.8ms preprocess, 42.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 42.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> chair
# Confidence ---> 0.56
# Class name --> chair
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 0.8ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 42.1ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> chair
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.32
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 0.7ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 chairs, 2 dining tables, 40.7ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 0.8ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 chairs, 1 dining table, 43.0ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> diningtable
# Speed: 0.7ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 1 refrigerator, 38.4ms
# Confidence ---> 0.86
# Class name --> chair
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.58
# Class name --> diningtable
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> refrigerator
# Speed: 0.8ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 48.0ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 0.9ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 chairs, 1 dining table, 33.5ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.61
# Class name --> diningtable
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 0.7ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 1 refrigerator, 32.4ms
# Confidence ---> 0.8
# Class name --> chair
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.51
# Class name --> diningtable
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> refrigerator
# Speed: 0.6ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 1 refrigerator, 40.7ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.55
# Class name --> diningtable
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> refrigerator
# Speed: 0.8ms preprocess, 40.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 35.8ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.45
# Class name --> diningtable
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.7ms preprocess, 35.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bottles, 2 chairs, 1 dining table, 1 refrigerator, 42.1ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> diningtable
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.33
# Class name --> refrigerator
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 1.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 chairs, 1 dining table, 33.1ms
# Confidence ---> 0.87
# Class name --> chair
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.44
# Class name --> diningtable
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 0.7ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 chairs, 1 dining table, 1 refrigerator, 34.2ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.36
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> refrigerator
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 0.9ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 2 chairs, 1 dining table, 38.2ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> diningtable
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.8ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 34.3ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 5.5ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 dining table, 33.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> chair
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.8ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 1 dining table, 33.0ms
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.44
# Class name --> diningtable
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.7ms preprocess, 33.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 1 dining table, 33.2ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.38
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> chair
# Speed: 1.0ms preprocess, 33.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 1 dining table, 45.8ms
# Confidence ---> 0.84
# Class name --> chair
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.29
# Class name --> diningtable
# Speed: 0.9ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 33.9ms
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.6ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 33.2ms
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.8ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 remote, 35.1ms
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.46
# Class name --> remote
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.9ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 remote, 1 keyboard, 32.6ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.29
# Class name --> keyboard
# Confidence ---> 0.27
# Class name --> remote
# Speed: 5.2ms preprocess, 32.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cell phones, 33.7ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 0.9ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 1 dining table, 1 laptop, 1 remote, 2 cell phones, 33.4ms
# Confidence ---> 0.78
# Class name --> cell phone
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.63
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.29
# Class name --> remote
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 0.8ms preprocess, 33.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bed, 1 laptop, 1 remote, 36.3ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> remote
# Confidence ---> 0.26
# Class name --> bed
# Speed: 0.8ms preprocess, 36.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 1 remote, 50.2ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.33
# Class name --> remote
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.8ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 1 remote, 43.4ms
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.74
# Class name --> remote
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.6ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 0.8ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.6ms
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.8ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.6ms
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.9ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 0.7ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 0.7ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 1.1ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.8ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.1ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 39.7ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.8ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.1ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.8ms preprocess, 41.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.4ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.8ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 38.7ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.35
# Class name --> chair
# Speed: 0.9ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 42.0ms
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.8ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 47.9ms
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Speed: 1.0ms preprocess, 47.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 39.3ms
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.8ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.9ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 45.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.7ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.5ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.6ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 37.9ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.9ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 1 laptop, 46.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.0ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 40.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.83
# Class name --> chair
# Confidence ---> 0.35
# Class name --> chair
# Speed: 0.8ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 38.7ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.8ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 49.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Speed: 1.1ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 38.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Speed: 0.9ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 42.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Speed: 0.9ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 38.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.81
# Class name --> chair
# Speed: 0.8ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 38.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.76
# Class name --> chair
# Confidence ---> 0.38
# Class name --> chair
# Speed: 0.9ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 38.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Speed: 0.8ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 44.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Speed: 0.9ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 40.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.4
# Class name --> chair
# Speed: 1.1ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 38.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.85
# Class name --> chair
# Confidence ---> 0.35
# Class name --> chair
# Speed: 1.0ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 40.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> chair
# Confidence ---> 0.52
# Class name --> chair
# Speed: 0.7ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 40.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.9ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 41.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.63
# Class name --> chair
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.45
# Class name --> chair
# Speed: 0.9ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 61.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.66
# Class name --> chair
# Confidence ---> 0.42
# Class name --> chair
# Speed: 0.7ms preprocess, 61.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 chairs, 38.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.82
# Class name --> chair
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.8ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 chairs, 39.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Speed: 0.8ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 44.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.32
# Class name --> chair
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.8ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 38.5ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.59
# Class name --> chair
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.8ms preprocess, 38.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 40.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.8ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.9ms preprocess, 44.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 chairs, 36.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.7ms preprocess, 36.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 2 couchs, 43.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.36
# Class name --> sofa
# Confidence ---> 0.34
# Class name --> sofa
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.9ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 chair, 51.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.9ms preprocess, 51.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 chairs, 39.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.8ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 chairs, 46.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.67
# Class name --> chair
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.9ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 42.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.81
# Class name --> chair
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.7ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 chairs, 41.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.8
# Class name --> chair
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.7ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 63.7ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.7
# Class name --> chair
# Confidence ---> 0.36
# ...
# Speed: 1.0ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.5ms
# Speed: 0.9ms preprocess, 48.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 326.1ms
# Confidence ---> 0.36
# Class name --> bed
# Speed: 1.1ms preprocess, 326.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 132.7ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 132.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 95.0ms
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> dog
# Speed: 1.0ms preprocess, 95.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 dog, 66.9ms
# Confidence ---> 0.39
# Class name --> dog
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.5ms preprocess, 66.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 84.3ms
# Confidence ---> 0.45
# Class name --> bed
# Speed: 0.8ms preprocess, 84.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 bed, 1 remote, 54.4ms
# Confidence ---> 0.81
# Class name --> remote
# Confidence ---> 0.43
# Class name --> cat
# Confidence ---> 0.43
# Class name --> bed
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 54.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.0ms
# Speed: 1.0ms preprocess, 73.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 67.2ms
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 1.3ms preprocess, 67.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.5ms
# Confidence ---> 0.34
# Class name --> person
# Speed: 3.8ms preprocess, 389.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 1.3ms preprocess, 89.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.4ms
# Speed: 0.9ms preprocess, 102.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.1ms
# Speed: 0.9ms preprocess, 68.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.4ms
# Speed: 0.7ms preprocess, 67.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.1ms
# Speed: 1.2ms preprocess, 64.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.0ms
# Speed: 4.4ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.3ms
# Speed: 4.2ms preprocess, 66.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.4ms
# Speed: 6.8ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 0.9ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 6.3ms preprocess, 58.5ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 1.1ms preprocess, 69.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 1.2ms preprocess, 54.1ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.0ms
# Speed: 0.8ms preprocess, 78.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.3ms preprocess, 53.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.0ms preprocess, 47.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 3.8ms preprocess, 54.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.1ms
# Speed: 0.8ms preprocess, 47.1ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 3.3ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.5ms
# Speed: 0.9ms preprocess, 115.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.5ms
# Speed: 0.9ms preprocess, 74.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.7ms
# Speed: 1.1ms preprocess, 76.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.1ms
# Speed: 4.7ms preprocess, 60.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.2ms
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.7ms preprocess, 76.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 0.9ms preprocess, 52.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.9ms
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.7ms preprocess, 53.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.0ms
# Speed: 1.0ms preprocess, 72.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.6ms
# Speed: 0.9ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.8ms
# Speed: 0.7ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.7ms
# Speed: 4.2ms preprocess, 49.7ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.2ms
# Speed: 1.2ms preprocess, 73.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.9ms
# Speed: 0.8ms preprocess, 65.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.8ms
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.8ms preprocess, 61.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.4ms
# Speed: 1.0ms preprocess, 72.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 5.3ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.5ms
# Speed: 2.5ms preprocess, 70.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.9ms
# Speed: 1.2ms preprocess, 73.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 0.8ms preprocess, 71.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.4ms
# Speed: 0.9ms preprocess, 65.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.1ms
# Speed: 1.0ms preprocess, 111.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.6ms
# Speed: 2.8ms preprocess, 62.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 136.3ms
# Speed: 1.1ms preprocess, 136.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.8ms
# Speed: 0.8ms preprocess, 65.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.6ms
# Speed: 1.2ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.5ms
# Speed: 0.9ms preprocess, 71.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.4ms
# Speed: 3.4ms preprocess, 66.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.9ms
# Speed: 0.9ms preprocess, 76.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.6ms
# Speed: 1.1ms preprocess, 73.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.4ms
# Speed: 1.1ms preprocess, 75.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.1ms
# Speed: 1.2ms preprocess, 84.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.9ms
# Speed: 3.7ms preprocess, 164.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.9ms
# Speed: 0.9ms preprocess, 94.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 13.8ms preprocess, 55.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.3ms
# Speed: 2.6ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.2ms preprocess, 68.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 2.1ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.7ms
# Speed: 1.5ms preprocess, 57.7ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 1.0ms preprocess, 83.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.5ms
# Speed: 0.8ms preprocess, 54.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.8ms
# Speed: 5.4ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 0.9ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.8ms
# Speed: 1.0ms preprocess, 103.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.8ms
# Speed: 0.9ms preprocess, 98.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.9ms
# Speed: 1.1ms preprocess, 95.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.0ms
# Speed: 0.7ms preprocess, 121.0ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.4ms
# Speed: 1.0ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.2ms
# Speed: 2.6ms preprocess, 78.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 1.0ms preprocess, 80.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.9ms
# Speed: 1.4ms preprocess, 74.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.2ms
# Speed: 10.1ms preprocess, 66.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.6ms
# Speed: 0.9ms preprocess, 74.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.8ms
# Speed: 1.2ms preprocess, 47.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 0.8ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.8ms
# Speed: 0.7ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 6.5ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.6ms
# Speed: 1.0ms preprocess, 91.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.3ms
# Speed: 0.9ms preprocess, 59.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 0.8ms preprocess, 54.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.1ms
# Speed: 0.9ms preprocess, 52.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 5.8ms preprocess, 51.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.8ms
# Speed: 1.4ms preprocess, 72.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 0.9ms preprocess, 70.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.6ms
# Speed: 0.9ms preprocess, 69.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.3ms
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.1ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 7.5ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.3ms
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.9ms preprocess, 49.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 47.2ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.8ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.0ms
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.8ms preprocess, 66.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 0.9ms preprocess, 70.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 0.7ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 5.5ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 4.9ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms

# %%
counting_regions = [
 
   {
       "name": "YOLOv8 Rectangle Region",
       "polygon": Polygon([(0, 0), (0, 1280), (720, 1280), (720, 0)]),  # Polygon points (tl,bl,br,tr)
       "counts": 0,
       "dragging": False,
       "region_color": (37, 255, 225),  # BGR Value
       "text_color": (0, 0, 0),  # Region Text Color
   },
]

results = model.track(frame, persist=True, classes=classes)

for region in counting_regions:
    for box in boxes:
        bbox_center = ((box[0] + box[2]) / 2, (box[1] + box[3]) / 2)  # Center of the bounding box
        if region["polygon"].contains(Point(bbox_center)):
            region["counts"] += 1

# Draw regions (Polygons/Rectangles)
 for region in counting_regions:
     region_label = str(region["counts"])
     region_color = region["region_color"]
     region_text_color = region["text_color"]
 
     polygon_coords = np.array(region["polygon"].exterior.coords, dtype=np.int32)
     centroid_x, centroid_y = int(region["polygon"].centroid.x), int(region["polygon"].centroid.y)
 
     text_size, _ = cv2.getTextSize(region_label, cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.7, thickness=line_thickness)
     text_x = centroid_x - text_size[0] // 2
     text_y = centroid_y + text_size[1] // 2
     cv2.rectangle(
                frame,
                (text_x - 5, text_y - text_size[1] - 5),
                (text_x + text_size[0] + 5, text_y + 5),
                region_color,
                -1,)
     cv2.putText(frame, region_label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, region_text_color, line_thickness)
     cv2.polylines(frame, [polygon_coords], isClosed=True, color=region_color, thickness=region_thickness)
